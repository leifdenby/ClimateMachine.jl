# %% [markdown]
# # Filters
# In this tutorial we show the result of applying filters
# available in the CliMA codebase in a 1 dimensional box advection setup.
# See [Filters API](https://clima.github.io/ClimateMachine.jl/latest/APIs/Numerics/Meshes/Mesh/#Filters-1) for filters interface details.

# %%
using ClimateMachine
const clima_dir = dirname(dirname(pathof(ClimateMachine)));
include(joinpath(clima_dir, "tutorials", "Numerics", "DGMethods", "Box1D.jl"))

output_dir = @__DIR__;
mkpath(output_dir);

# %% [markdown]
# The unfiltered result of the box advection test for order 4 polynomial is:

# %%
run_box1D(4, 0.0, 1.0, 1.0, joinpath(output_dir, "box_1D_4_no_filter.svg"))
# Out:
# ┌ Info: Model composition
# │     param_set = Main.##364.EarthParameterSet()
# │     init_q = 0.0
# │     amplitude = 1.0
# │     velo = 1.0
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/driver_configs.jl:102
# ┌ Info: Establishing single stack configuration for Box1D
# │     precision        = Float64
# │     polynomial order = 4
# │     domain_min       = 0.00 m x0.00 m x0.00 m
# │     domain_max       = 500.00 m x500.00 m x350.00 m
# │     #vert elems      = 128
# │     MPI ranks        = 1
# │     min(Δ_horz)      = 86.34 m
# │     min(Δ_vert)      = 0.47 m
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/driver_configs.jl:380
# ┌ Info: Initializing Box1D
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/solver_configs.jl:151
# ┌ Info: Starting Box1D
# │     dt              = 4.71698e-01
# │     timeend         =   450.00
# │     number of steps = 954
# │     norm(Q)         = 3.5422793587682572e+03
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/Driver.jl:629
# ┌ Info: Finished
# │     norm(Q)            = 3.5314527000886205e+03
# │     norm(Q) / norm(Q₀) = 9.9694358982364351e-01
# │     norm(Q) - norm(Q₀) = -1.0826658679636694e+01
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/Driver.jl:667

# %% [markdown]
# ![](box_1D_4_no_filter.svg)

# %% [markdown]
# Below we show results for the same box advection test
# but using different filters.

# %% [markdown]
# `TMARFilter()`:

# %%
run_box1D(
    4,
    0.0,
    1.0,
    1.0,
    joinpath(output_dir, "box_1D_4_tmar.svg");
    tmar_filter = true,
)
# Out:
# ┌ Info: Model composition
# │     param_set = Main.##364.EarthParameterSet()
# │     init_q = 0.0
# │     amplitude = 1.0
# │     velo = 1.0
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/driver_configs.jl:102
# ┌ Info: Establishing single stack configuration for Box1D
# │     precision        = Float64
# │     polynomial order = 4
# │     domain_min       = 0.00 m x0.00 m x0.00 m
# │     domain_max       = 500.00 m x500.00 m x350.00 m
# │     #vert elems      = 128
# │     MPI ranks        = 1
# │     min(Δ_horz)      = 86.34 m
# │     min(Δ_vert)      = 0.47 m
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/driver_configs.jl:380
# ┌ Info: Initializing Box1D
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/solver_configs.jl:151
# ┌ Info: Starting Box1D
# │     dt              = 4.71698e-01
# │     timeend         =   450.00
# │     number of steps = 954
# │     norm(Q)         = 3.5422793587682572e+03
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/Driver.jl:629
# ┌ Info: Finished
# │     norm(Q)            = 3.5142417383377237e+03
# │     norm(Q) / norm(Q₀) = 9.9208486468998225e-01
# │     norm(Q) - norm(Q₀) = -2.8037620430533480e+01
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/Driver.jl:667

# %% [markdown]
# ![](box_1D_4_tmar.svg)

# %% [markdown]
# `CutoffFilter(grid, Nc=1)`:

# %%
run_box1D(
    4,
    0.0,
    1.0,
    1.0,
    joinpath(output_dir, "box_1D_4_cutoff_1.svg");
    cutoff_filter = true,
    cutoff_param = 1,
)
# Out:
# ┌ Info: Model composition
# │     param_set = Main.##364.EarthParameterSet()
# │     init_q = 0.0
# │     amplitude = 1.0
# │     velo = 1.0
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/driver_configs.jl:102
# ┌ Info: Establishing single stack configuration for Box1D
# │     precision        = Float64
# │     polynomial order = 4
# │     domain_min       = 0.00 m x0.00 m x0.00 m
# │     domain_max       = 500.00 m x500.00 m x350.00 m
# │     #vert elems      = 128
# │     MPI ranks        = 1
# │     min(Δ_horz)      = 86.34 m
# │     min(Δ_vert)      = 0.47 m
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/driver_configs.jl:380
# ┌ Info: Initializing Box1D
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/solver_configs.jl:151
# ┌ Info: Starting Box1D
# │     dt              = 4.71698e-01
# │     timeend         =   450.00
# │     number of steps = 954
# │     norm(Q)         = 3.5422793587682572e+03
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/Driver.jl:629
# ┌ Info: Finished
# │     norm(Q)            = 2.1874634549845996e+03
# │     norm(Q) / norm(Q₀) = 6.1752991038663807e-01
# │     norm(Q) - norm(Q₀) = -1.3548159037836576e+03
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/Driver.jl:667

# %% [markdown]
# ![](box_1D_4_cutoff_1.svg)

# %% [markdown]
# `CutoffFilter(grid, Nc=3)`:

# %%
run_box1D(
    4,
    0.0,
    1.0,
    1.0,
    joinpath(output_dir, "box_1D_4_cutoff_3.svg");
    cutoff_filter = true,
    cutoff_param = 3,
)
# Out:
# ┌ Info: Model composition
# │     param_set = Main.##364.EarthParameterSet()
# │     init_q = 0.0
# │     amplitude = 1.0
# │     velo = 1.0
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/driver_configs.jl:102
# ┌ Info: Establishing single stack configuration for Box1D
# │     precision        = Float64
# │     polynomial order = 4
# │     domain_min       = 0.00 m x0.00 m x0.00 m
# │     domain_max       = 500.00 m x500.00 m x350.00 m
# │     #vert elems      = 128
# │     MPI ranks        = 1
# │     min(Δ_horz)      = 86.34 m
# │     min(Δ_vert)      = 0.47 m
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/driver_configs.jl:380
# ┌ Info: Initializing Box1D
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/solver_configs.jl:151
# ┌ Info: Starting Box1D
# │     dt              = 4.71698e-01
# │     timeend         =   450.00
# │     number of steps = 954
# │     norm(Q)         = 3.5422793587682572e+03
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/Driver.jl:629
# ┌ Info: Finished
# │     norm(Q)            = 3.5069120229875743e+03
# │     norm(Q) / norm(Q₀) = 9.9001565596650709e-01
# │     norm(Q) - norm(Q₀) = -3.5367335780682879e+01
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/Driver.jl:667

# %% [markdown]
# ![](box_1D_4_cutoff_3.svg)

# %% [markdown]
# `ExponentialFilter(grid, Nc=1, s=4)`:

# %%
run_box1D(
    4,
    0.0,
    1.0,
    1.0,
    joinpath(output_dir, "box_1D_4_exp_1_4.svg");
    exp_filter = true,
    exp_param_1 = 1,
    exp_param_2 = 4,
)
# Out:
# ┌ Info: Model composition
# │     param_set = Main.##364.EarthParameterSet()
# │     init_q = 0.0
# │     amplitude = 1.0
# │     velo = 1.0
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/driver_configs.jl:102
# ┌ Info: Establishing single stack configuration for Box1D
# │     precision        = Float64
# │     polynomial order = 4
# │     domain_min       = 0.00 m x0.00 m x0.00 m
# │     domain_max       = 500.00 m x500.00 m x350.00 m
# │     #vert elems      = 128
# │     MPI ranks        = 1
# │     min(Δ_horz)      = 86.34 m
# │     min(Δ_vert)      = 0.47 m
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/driver_configs.jl:380
# ┌ Info: Initializing Box1D
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/solver_configs.jl:151
# ┌ Info: Starting Box1D
# │     dt              = 4.71698e-01
# │     timeend         =   450.00
# │     number of steps = 954
# │     norm(Q)         = 3.5422793587682572e+03
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/Driver.jl:629
# ┌ Info: Finished
# │     norm(Q)            = 3.4666722428260550e+03
# │     norm(Q) / norm(Q₀) = 9.7865580088847293e-01
# │     norm(Q) - norm(Q₀) = -7.5607115942202199e+01
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/Driver.jl:667

# %% [markdown]
# ![](box_1D_4_exp_1_4.svg)

# %% [markdown]
# `ExponentialFilter(grid, Nc=1, s=8)`:

# %%
run_box1D(
    4,
    0.0,
    1.0,
    1.0,
    joinpath(output_dir, "box_1D_4_exp_1_8.svg");
    exp_filter = true,
    exp_param_1 = 1,
    exp_param_2 = 8,
)
# Out:
# ┌ Info: Model composition
# │     param_set = Main.##364.EarthParameterSet()
# │     init_q = 0.0
# │     amplitude = 1.0
# │     velo = 1.0
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/driver_configs.jl:102
# ┌ Info: Establishing single stack configuration for Box1D
# │     precision        = Float64
# │     polynomial order = 4
# │     domain_min       = 0.00 m x0.00 m x0.00 m
# │     domain_max       = 500.00 m x500.00 m x350.00 m
# │     #vert elems      = 128
# │     MPI ranks        = 1
# │     min(Δ_horz)      = 86.34 m
# │     min(Δ_vert)      = 0.47 m
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/driver_configs.jl:380
# ┌ Info: Initializing Box1D
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/solver_configs.jl:151
# ┌ Info: Starting Box1D
# │     dt              = 4.71698e-01
# │     timeend         =   450.00
# │     number of steps = 954
# │     norm(Q)         = 3.5422793587682572e+03
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/Driver.jl:629
# ┌ Info: Finished
# │     norm(Q)            = 3.5071549751653261e+03
# │     norm(Q) / norm(Q₀) = 9.9008424236332826e-01
# │     norm(Q) - norm(Q₀) = -3.5124383602931175e+01
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/Driver.jl:667

# %% [markdown]
# ![](box_1D_4_exp_1_8.svg)

# %% [markdown]
# `ExponentialFilter(grid, Nc=1, s=32)`:

# %%
run_box1D(
    4,
    0.0,
    1.0,
    1.0,
    joinpath(output_dir, "box_1D_4_exp_1_32.svg");
    exp_filter = true,
    exp_param_1 = 1,
    exp_param_2 = 32,
)
# Out:
# ┌ Info: Model composition
# │     param_set = Main.##364.EarthParameterSet()
# │     init_q = 0.0
# │     amplitude = 1.0
# │     velo = 1.0
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/driver_configs.jl:102
# ┌ Info: Establishing single stack configuration for Box1D
# │     precision        = Float64
# │     polynomial order = 4
# │     domain_min       = 0.00 m x0.00 m x0.00 m
# │     domain_max       = 500.00 m x500.00 m x350.00 m
# │     #vert elems      = 128
# │     MPI ranks        = 1
# │     min(Δ_horz)      = 86.34 m
# │     min(Δ_vert)      = 0.47 m
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/driver_configs.jl:380
# ┌ Info: Initializing Box1D
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/solver_configs.jl:151
# ┌ Info: Starting Box1D
# │     dt              = 4.71698e-01
# │     timeend         =   450.00
# │     number of steps = 954
# │     norm(Q)         = 3.5422793587682572e+03
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/Driver.jl:629
# ┌ Info: Finished
# │     norm(Q)            = 3.5271758961151036e+03
# │     norm(Q) / norm(Q₀) = 9.9573623051051352e-01
# │     norm(Q) - norm(Q₀) = -1.5103462653153656e+01
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/Driver.jl:667

# %% [markdown]
# ![](box_1D_4_exp_1_32.svg)

# %% [markdown]
# `BoydVandevenFilter(grid, Nc=1, s=4)`:

# %%
run_box1D(
    4,
    0.0,
    1.0,
    1.0,
    joinpath(output_dir, "box_1D_4_boyd_1_4.svg");
    boyd_filter = true,
    boyd_param_1 = 1,
    boyd_param_2 = 4,
)
# Out:
# ┌ Info: Model composition
# │     param_set = Main.##364.EarthParameterSet()
# │     init_q = 0.0
# │     amplitude = 1.0
# │     velo = 1.0
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/driver_configs.jl:102
# ┌ Info: Establishing single stack configuration for Box1D
# │     precision        = Float64
# │     polynomial order = 4
# │     domain_min       = 0.00 m x0.00 m x0.00 m
# │     domain_max       = 500.00 m x500.00 m x350.00 m
# │     #vert elems      = 128
# │     MPI ranks        = 1
# │     min(Δ_horz)      = 86.34 m
# │     min(Δ_vert)      = 0.47 m
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/driver_configs.jl:380
# ┌ Info: Initializing Box1D
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/solver_configs.jl:151
# ┌ Info: Starting Box1D
# │     dt              = 4.71698e-01
# │     timeend         =   450.00
# │     number of steps = 954
# │     norm(Q)         = 3.5422793587682572e+03
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/Driver.jl:629
# ┌ Info: Finished
# │     norm(Q)            = 3.4806217850623293e+03
# │     norm(Q) / norm(Q₀) = 9.8259381390874612e-01
# │     norm(Q) - norm(Q₀) = -6.1657573705927916e+01
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/Driver.jl:667

# %% [markdown]
# ![](box_1D_4_boyd_1_4.svg)

# %% [markdown]
# `BoydVandevenFilter(grid, Nc=1, s=8)`:

# %%
run_box1D(
    4,
    0.0,
    1.0,
    1.0,
    joinpath(output_dir, "box_1D_4_boyd_1_8.svg");
    boyd_filter = true,
    boyd_param_1 = 1,
    boyd_param_2 = 8,
)
# Out:
# ┌ Info: Model composition
# │     param_set = Main.##364.EarthParameterSet()
# │     init_q = 0.0
# │     amplitude = 1.0
# │     velo = 1.0
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/driver_configs.jl:102
# ┌ Info: Establishing single stack configuration for Box1D
# │     precision        = Float64
# │     polynomial order = 4
# │     domain_min       = 0.00 m x0.00 m x0.00 m
# │     domain_max       = 500.00 m x500.00 m x350.00 m
# │     #vert elems      = 128
# │     MPI ranks        = 1
# │     min(Δ_horz)      = 86.34 m
# │     min(Δ_vert)      = 0.47 m
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/driver_configs.jl:380
# ┌ Info: Initializing Box1D
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/solver_configs.jl:151
# ┌ Info: Starting Box1D
# │     dt              = 4.71698e-01
# │     timeend         =   450.00
# │     number of steps = 954
# │     norm(Q)         = 3.5422793587682572e+03
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/Driver.jl:629
# ┌ Info: Finished
# │     norm(Q)            = 3.4899368358503070e+03
# │     norm(Q) / norm(Q₀) = 9.8522349097385953e-01
# │     norm(Q) - norm(Q₀) = -5.2342522917950191e+01
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/Driver.jl:667

# %% [markdown]
# ![](box_1D_4_boyd_1_8.svg)

# %% [markdown]
# `BoydVandevenFilter(grid, Nc=1, s=32)`:

# %%
run_box1D(
    4,
    0.0,
    1.0,
    1.0,
    joinpath(output_dir, "box_1D_4_boyd_1_32.svg");
    boyd_filter = true,
    boyd_param_1 = 1,
    boyd_param_2 = 32,
)
# Out:
# ┌ Info: Model composition
# │     param_set = Main.##364.EarthParameterSet()
# │     init_q = 0.0
# │     amplitude = 1.0
# │     velo = 1.0
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/driver_configs.jl:102
# ┌ Info: Establishing single stack configuration for Box1D
# │     precision        = Float64
# │     polynomial order = 4
# │     domain_min       = 0.00 m x0.00 m x0.00 m
# │     domain_max       = 500.00 m x500.00 m x350.00 m
# │     #vert elems      = 128
# │     MPI ranks        = 1
# │     min(Δ_horz)      = 86.34 m
# │     min(Δ_vert)      = 0.47 m
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/driver_configs.jl:380
# ┌ Info: Initializing Box1D
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/solver_configs.jl:151
# ┌ Info: Starting Box1D
# │     dt              = 4.71698e-01
# │     timeend         =   450.00
# │     number of steps = 954
# │     norm(Q)         = 3.5422793587682572e+03
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/Driver.jl:629
# ┌ Info: Finished
# │     norm(Q)            = 3.5060209628232587e+03
# │     norm(Q) / norm(Q₀) = 9.8976410602533438e-01
# │     norm(Q) - norm(Q₀) = -3.6258395944998483e+01
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/Driver.jl:667

# %% [markdown]
# ![](box_1D_4_boyd_1_32.svg)

# %% [markdown]
# `ExponentialFilter(grid, Nc=1, s=8)` and `TMARFilter()`:

# %%
run_box1D(
    4,
    0.0,
    1.0,
    1.0,
    joinpath(output_dir, "box_1D_4_tmar_exp_1_8.svg");
    exp_filter = true,
    tmar_filter = true,
    exp_param_1 = 1,
    exp_param_2 = 8,
)
# Out:
# ┌ Info: Model composition
# │     param_set = Main.##364.EarthParameterSet()
# │     init_q = 0.0
# │     amplitude = 1.0
# │     velo = 1.0
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/driver_configs.jl:102
# ┌ Info: Establishing single stack configuration for Box1D
# │     precision        = Float64
# │     polynomial order = 4
# │     domain_min       = 0.00 m x0.00 m x0.00 m
# │     domain_max       = 500.00 m x500.00 m x350.00 m
# │     #vert elems      = 128
# │     MPI ranks        = 1
# │     min(Δ_horz)      = 86.34 m
# │     min(Δ_vert)      = 0.47 m
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/driver_configs.jl:380
# ┌ Info: Initializing Box1D
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/solver_configs.jl:151
# ┌ Info: Starting Box1D
# │     dt              = 4.71698e-01
# │     timeend         =   450.00
# │     number of steps = 954
# │     norm(Q)         = 3.5422793587682572e+03
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/Driver.jl:629
# ┌ Info: Finished
# │     norm(Q)            = 3.4929736646876909e+03
# │     norm(Q) / norm(Q₀) = 9.8608080021737443e-01
# │     norm(Q) - norm(Q₀) = -4.9305694080566354e+01
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/Driver.jl:667

# %% [markdown]
# ![](box_1D_4_tmar_exp_1_8.svg)

# %% [markdown]
# `BoydVandevenFilter(grid, Nc=1, s=8)` and `TMARFilter()`:

# %%
run_box1D(
    4,
    0.0,
    1.0,
    1.0,
    joinpath(output_dir, "box_1D_4_tmar_boyd_1_8.svg");
    boyd_filter = true,
    tmar_filter = true,
    boyd_param_1 = 1,
    boyd_param_2 = 8,
)
# Out:
# ┌ Info: Model composition
# │     param_set = Main.##364.EarthParameterSet()
# │     init_q = 0.0
# │     amplitude = 1.0
# │     velo = 1.0
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/driver_configs.jl:102
# ┌ Info: Establishing single stack configuration for Box1D
# │     precision        = Float64
# │     polynomial order = 4
# │     domain_min       = 0.00 m x0.00 m x0.00 m
# │     domain_max       = 500.00 m x500.00 m x350.00 m
# │     #vert elems      = 128
# │     MPI ranks        = 1
# │     min(Δ_horz)      = 86.34 m
# │     min(Δ_vert)      = 0.47 m
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/driver_configs.jl:380
# ┌ Info: Initializing Box1D
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/solver_configs.jl:151
# ┌ Info: Starting Box1D
# │     dt              = 4.71698e-01
# │     timeend         =   450.00
# │     number of steps = 954
# │     norm(Q)         = 3.5422793587682572e+03
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/Driver.jl:629
# ┌ Info: Finished
# │     norm(Q)            = 3.4774323409688736e+03
# │     norm(Q) / norm(Q₀) = 9.8169342075213051e-01
# │     norm(Q) - norm(Q₀) = -6.4847017799383593e+01
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/Driver.jl:667

# %% [markdown]
# ![](box_1D_4_tmar_boyd_1_8.svg)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
